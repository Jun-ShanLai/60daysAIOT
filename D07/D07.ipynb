# %% [markdown]
# # 作業: 安裝MongoDB、Robo 3T 工具

# %% [markdown]
# # [作業目標]
# * 成功安裝 Mongo資料庫及GUI工具
# * 能夠使用命令提示工具(cmd、terminal)操作Mongo資料
# * 能夠使用 Robo 3T 操作Mongo資料

# %% [markdown]
# # [作業重點]
# * 了解 DB、Collection、Document 在 Mongo 中所代表的意義。
# * 能夠手動對資料做增刪改查的操作。

# %% [markdown]
# # [作業1]
# * 至以下網站下載 MongoDB 和 Robo 3T 工具，並成功運行。
#
# Mongo: https://www.mongodb.com/try/download/community
#
# Robo 3T: https://robomongo.org/

# %% [markdown]
# # [作業2]
# * 分別使用命令提示工具、Robo 3T圖形介面工具，照以下步驟操作資料。
#
#
# 1. 新增一個 DB 名稱自訂。
# 2. 在該 DB 中新增一個 Collection 名稱為 Member
# 3. 在 Collection 中新增一筆會員資料，資料結構如下：
#     * name : Kevin
#     * email : test@abc.com
#     * phone: 0912345678
# 4. 將上述那筆資料的 name 欄位改成 Cathy
# 5. 加入新的欄位 age 到上述那筆資料中，並將值的部分設為 25
#
# `註: 請將作業結果截圖下來。`

# %% [markdown]
# ## 作業一

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![001.png](../img/D07_01.png)

# %% [markdown]
# ## 作業二

# %% [markdown]
# * 分別使用命令提示工具、Robo 3T圖形介面工具，照以下步驟操作資料。
#
#
# 1. 新增一個 DB 名稱自訂。
# 2. 在該 DB 中新增一個 Collection 名稱為 Member
# 3. 在 Collection 中新增一筆會員資料，資料結構如下：
#     * name : Kevin
#     * email : test@abc.com
#     * phone: 0912345678
# 4. 將上述那筆資料的 name 欄位改成 Cathy
# 5. 加入新的欄位 age 到上述那筆資料中，並將值的部分設為 25
#
# `註: 請將作業結果截圖下來。`

# %% [markdown]
# ## 1.新增一個DB
#
# 從MongoDB Shell去新增一個名為Test的資料庫
#
# --------------------------
# MongoDB Shell - 確認版本
# ![002.png](../img/D07_02.png)
#
# ---------------------------------------
#
# 進入命令列模式(MongoDB Shell)
# ![003.png](../img/D07_03.png)
#
# --------------
#
# 從MongoDB Shell去新增一筆資料
# ![004.png](../img/D07_04.png)

# %% [markdown]
# ## 2.在該 DB 中新增一個 Collection 名稱為 member
#
# 嘗試從Robo 3T查看前面所新增的資料,並新增一個 Collection 名稱為 member
#
# --------------------------
# 查詢前面所新增的資料
#
# ![005.png](../img/D07_05.png)

# %% [markdown]
# ## 3.在 Collection 中新增一筆會員資料
#
# 在 Collection 中新增一筆會員資料，資料結構如下：
# name : Kevin
# email : test@abc.com
# phone: 0912345678
#
# --------------------------
#
#
# ![006.png](../img/D07_06.png)

# %% [markdown]
# ## 4.將上述那筆資料的 name 欄位改成 Cathy
# ## 5.加入新的欄位 age 到上述那筆資料中，並將值的部分設為 25
#
# ---------------
# ![007.png](../img/D07_07.png)
